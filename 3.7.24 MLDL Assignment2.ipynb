# %%
import pandas as pd
import numpy as np
df=pd.read_csv('H_DDataset.csv')
df
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 0      40    1                2           140          289
# 1      49    0                3           160          180
# 2      37    1                2           130          283
# 3      48    0                4           138          214
# 4      54    1                3           150          195
# ...   ...  ...              ...           ...          ...
# 1185   45    1                1           110          264
# 1186   68    1                4           144          193
# 1187   57    1                4           130          131
# 1188   57    0                2           130          236
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0             172                0
# 1                       0            0             156                0
# ...

# %%
correlation = df['max heart rate'].corr(df['resting bp s'])

print(correlation)
# Out:
# -0.10135690105904019

# %%
CT = pd.crosstab(df['chest pain type'], df['fasting blood sugar'],margins=True)
CT
observed = CT.values
observed
# Out:
# array([[  48,   18,   66],
#        [ 192,   24,  216],
#        [ 225,   58,  283],
#        [ 471,  154,  625],
#        [ 936,  254, 1190]])

# %%
expected = np.zeros(observed.shape)
row_sums = observed.sum(axis=1)
col_sums = observed.sum(axis=0)
total = observed.sum()

for i in range(len(row_sums)):
    for j in range(len(col_sums)):
        expected[i, j] = (row_sums[i] * col_sums[j]) / total

expected
# Out:
# array([[  51.91260504,   14.08739496,   66.        ],
#        [ 169.89579832,   46.10420168,  216.        ],
#        [ 222.59495798,   60.40504202,  283.        ],
#        [ 491.59663866,  133.40336134,  625.        ],
#        [ 936.        ,  254.        , 1190.        ]])

# %%
from scipy.stats import chi2
chi_square_stat = ((observed - expected) ** 2 / expected).sum()

# Degrees of freedom
dof = (observed.shape[0] - 1) * (observed.shape[1] - 1)

# p-value
p_value = 1 - chi2.cdf(chi_square_stat, dof)

chi_square_stat
# Out:
# 19.01974426864553

# %%
p_value
# Out:
# 0.014754411026497438

# %%
dof
# Out:
# 8
