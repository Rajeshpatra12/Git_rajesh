# %%
import pandas as pd
import matplotlib.pyplot as plt
df= pd.read_csv("C:\\Users\\rhpat\\OneDrive\\Documents\\dataset.csv")
df
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 0      40    1                2           140          289
# 1      49    0                3           160          180
# 2      37    1                2           130          283
# 3      48    0                4           138          214
# 4      54    1                3           150          195
# ...   ...  ...              ...           ...          ...
# 1185   45    1                1           110          264
# 1186   68    1                4           144          193
# 1187   57    1                4           130          131
# 1188   57    0                2           130          236
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0             172                0
# 1                       0            0             156                0
# ...

# %%
print(df.head())
disease_distribution = df['target'].value_counts()
print(disease_distribution)
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0
# target
# 1    629
# 0    561
# Name: count, dtype: int64

# %%
#1.Plot the Distribution of disease
from matplotlib import pyplot as plt
plt.figure(figsize=(10,10)) # set the figure size
plt.pie(disease_distribution, labels=['No Disease', 'Disease'], autopct='%1.1f%%' , startangle=90, colors=['#FFFF00','#A020F0'])
plt.title('Distribution of Disease')
plt.ylabel('') # Hide the y-axis label
plt.show()

# %%
#2. Plot attribute statistics
plt.figure(figsize=(14,10))
df.hist(bins=20, figsize=(14, 10))
plt.suptitle('Attribute Statistics')
plt.show()

# %%
'''3. Find the five-number summary of
(I)max heart rate
(ii) resting bp s
(iii) cholesterol'''
import statistics as st
p=pd.read_csv("C:\\Users\\rhpat\\OneDrive\\Documents\\dataset.csv")
a=p.cholesterol
print(st.mean(a))
print(st.median(a))
print(min(a))
print(max(a))

b=p['resting bp s']
print(st.mean(b))
print(st.median(b))
print(min(b))
print(max(b))

t=p["max heart rate"]
print(st.mean(t))
print(st.median(t))
print(min(t))
print(max(t))

categorical_columns = ['sex', 'chest pain type', 'fasting blood sugar', 'resting ecg', 'exercise angina', 'ST slope']
plt.figure(figsize=(15, 10))
for i, column in enumerate(categorical_columns, 1):
    plt.subplot(2, 3, i)
    df[column].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
    plt.title(column)
    plt.ylabel('')
plt.tight_layout()

plt.show()
# Out:
# 210.36386554621848
# 229.0
# 0
# 603
# 132.15378151260504
# 130.0
# 0
# 200
# 139.7327731092437
# 140.5
# 60
# 202
